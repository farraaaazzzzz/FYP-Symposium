# %%
# Install necessary libraries in Jupyter if not installed
# !pip install pandas numpy openpyxl matplotlib seaborn tabulate

# %%
# BLOCK 1: Load All Files and Print Columns Neatly

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display
from tabulate import tabulate
import os

# Set paths
merged_log_path = r'E:\FYP\FYP Symposium\Merged Log (49).xlsx'
stock_data_path = r'E:\FYP\FYP Symposium\Trading Simulation Experiment Data Turn Wise.xlsx'
dta_path = r'E:\FYP\FYP Symposium\SurveysClean.dta'

# Load Data
merged_log = pd.read_excel(merged_log_path)
stock_xls = pd.ExcelFile(stock_data_path)
stock_tables = {stock: pd.read_excel(stock_xls, sheet_name=stock) for stock in ['TSLA', 'XOM', 'NFLX', 'PG']}
strategy = pd.read_stata(dta_path)

# Show loaded columns for verification (pretty print using tabulate)
print("Merged Log Columns:\n")
print(tabulate([[col] for col in merged_log.columns], headers=["Merged Log Columns"], tablefmt="github"))

print("\nStrategy Columns:\n")
print(tabulate([[col] for col in strategy.columns], headers=["Strategy Columns"], tablefmt="github"))

print(merged_log.head(1))
# Out:
# Merged Log Columns:
#
# | Merged Log Columns    |
# |-----------------------|
# | Date                  |
# | Real Time             |
# | Simulation Time       |
# | Seconds left          |
# | Participant_ID        |
# | turn                  |
# | action                |
# | ticker                |
# | News Sentiment        |
# | News Truth            |
# | quantity              |
# | Stock Price           |
# | Total Stock           |
# | cash_before           |
# | cash_after            |
# | stockportfolio_before |
# | stockportfolio_after  |
# | Total_assets          |
# | total_TSLA_holding    |
# | total_XOM_holding     |
# | total_NFLX_holding    |
# | total_PG_holding      |
# | TSLA_value            |
# | XOM_value             |
# | NFLX_value            |
# | PG_value              |
#
# Strategy Columns:
#
# | Strategy Columns   |
# |--------------------|
# | TimePre            |
# | Name               |
# | Participant_ID     |
# | PRM1_5             |
# | PRM1_6             |
# | PRM1_7             |
# | PRM1_8             |
# | PRM1_9             |
# | PRM1_10            |
# | PRM1_11            |
# | PRM1_12            |
# | PRM1_12a           |
# | PRM2a_1            |
# | PRM2a_2            |
# | PRM2a_3            |
# | PRM2a_4            |
# | PRM2b_1            |
# | PRM2b_2            |
# | PRM2b_4            |
# | PRM2b_5            |
# | PRM2b_6            |
# | PRM2b_7            |
# | PRM2b_8            |
# | PRM2b_9            |
# | PRM2b_10           |
# | PRM2b_11           |
# | PRM2b_12           |
# | PRM2b_13           |
# | PRM2b_13a          |
# | PRM2b_14           |
# | PRM2b_14a          |
# | PRM3_1             |
# | PRM3_2             |
# | PRM3_3             |
# | PRM3_4             |
# | PRM3_5             |
# | PRM3_6             |
# | PRM3_7             |
# | PRM3_8             |
# | PRM3_9             |
# | PRM3_10            |
# | PRM3_11            |
# | PRM3_12            |
# | PRM4a_1            |
# | PRM4a_1a           |
# | PRM4a_2            |
# | PRM4a_2a           |
# | PRM4a_3            |
# | PRM4a_3a           |
# | PRM4a_3b           |
# | PRM4a_4            |
# | PRM4a_4a           |
# | PRM4a_4b           |
# | PRM4a_4c           |
# | PRM4b_1            |
# | PRM4b_2            |
# | PRM4b_3            |
# | PRM4b_4            |
# | PRM4b_5            |
# | PRM4b_5a           |
# | PRM4b_6            |
# | PRM4b_7            |
# | PRM4b_7a           |
# | PRM4b_8            |
# | PRM4c_1            |
# | PRM4c_2            |
# | PRM4c_3            |
# | PRM4c_4            |
# | PRM4c_5            |
# | PRM4c_6            |
# | PRM4c_7            |
# | PRM4c_8            |
# | PRM4c_8a           |
# | PRM4c_9            |
# | PRM2b_3            |
# | PRM4b_4a           |
# | PRM4b_5b           |
# | PRM4b_5c           |
# | TimePost           |
# | POM2_1             |
# | POM2_2             |
# | POM2_2a            |
# | POM2_3             |
# | POM2_3a            |
# | POM2_4             |
# | POM2_4a            |
# | POM2_5             |
# | POM2_5a            |
# | POM2_6             |
# | POM2_7             |
# | POM2_8             |
# | POM2_9             |
# | POM2_9a            |
# | POM3_1             |
# | POM3_2             |
# | POM3_3             |
# | POM4a_1            |
# | POM4a_2            |
# | POM4a_3            |
# | POM4a_4            |
# | POM4a_5            |
# | POM4a_6            |
# | POM4a_7            |
# | POM4a_8            |
# | POM4b_1_T          |
# | POM4b_1_X          |
# | POM4b_1_N          |
# | POM4b_1_P          |
# | POM4b_2_T          |
# | POM4b_2_X          |
# | POM4b_2_N          |
# | POM4b_2_P          |
# | POM4b_3_G          |
# | POM4b_3_DT         |
# | POM4b_3_NH         |
# | POM4b_4_OC         |
# | POM4b_4_HL         |
# | POM4b_4_V          |
# | POM4b_4_BB         |
# | POM4b_4_MACD       |
# | POM5_1             |
# | POM5_2             |
# | POM5_3             |
# | POM5_4             |
# | Stock_1st          |
# | Stock_2nd          |
# | Stock_3rd          |
# | Stock_4th          |
# | Risky_1st          |
# | Risky_2nd          |
# | Risky_3rd          |
# | Risky_4th          |
# | DecisionFactor_1st |
# | DecisionFactor_2nd |
# | DecisionFactor_3rd |
# | Indicator_1st      |
# | Indicator_2nd      |
# | Indicator_3rd      |
# | Indicator_4th      |
# | Indicator_5th      |
#          Date Real Time Simulation Time  Seconds left Participant_ID  turn  \
# 0  2025-04-23  10:50:33         0:00:55             5          E0070     1
#
#   action ticker News Sentiment News Truth  ...  stockportfolio_after  \
# 0    Buy   TSLA       Negative      False  ...                3378.0
#
#    Total_assets  total_TSLA_holding  total_XOM_holding  total_NFLX_holding  \
# 0       10000.0                  10                  0                   0
#
#    total_PG_holding  TSLA_value  XOM_value  NFLX_value  PG_value
# 0                 0      3378.0        0.0         0.0       0.0
#
# [1 rows x 26 columns]

# %%
# BLOCK 2: Rename Columns for Consistency

# Rename Merged Log Columns to match our expectations
merged_log.rename(columns={
    'News Sentiment': 'news_sentiment',
    'News Truth': 'news_truth'
}, inplace=True)

# Rename Strategy Columns if needed
if 'participant_id' not in strategy.columns:
    if 'ResponseID' in strategy.columns:
        strategy.rename(columns={'ResponseID': 'participant_id'}, inplace=True)
    elif 'ResponseId' in strategy.columns:
        strategy.rename(columns={'ResponseId': 'participant_id'}, inplace=True)

# Check after renaming
print("Merged Log Columns (After Rename):\n")
print(tabulate([[col] for col in merged_log.columns], headers=["Merged Log Columns"], tablefmt="github"))

print("\nStrategy Columns (After Rename):\n")
print(tabulate([[col] for col in strategy.columns], headers=["Strategy Columns"], tablefmt="github"))


import pandas as pd
from tabulate import tabulate

# Assuming merged_log and strategy are already available after renaming

# Export both merged_log and strategy to Excel with separate sheets
output_file = r'E:\FYP\FYP Symposium\Renamed_Merged_Log_and_Strategy.xlsx'  # Specify the file path

with pd.ExcelWriter(output_file, engine='xlsxwriter') as writer:
    merged_log.to_excel(writer, sheet_name='Merged_Log', index=False)  # Save merged_log to the first sheet
    strategy.to_excel(writer, sheet_name='Strategy', index=False)  # Save strategy to the second sheet

print(f"The renamed merged_log and strategy have been exported to: {output_file}")
# Out:
# Merged Log Columns (After Rename):
#
# | Merged Log Columns    |
# |-----------------------|
# | Date                  |
# | Real Time             |
# | Simulation Time       |
# | Seconds left          |
# | Participant_ID        |
# | turn                  |
# | action                |
# | ticker                |
# | news_sentiment        |
# | news_truth            |
# | quantity              |
# | Stock Price           |
# | Total Stock           |
# | cash_before           |
# | cash_after            |
# | stockportfolio_before |
# | stockportfolio_after  |
# | Total_assets          |
# | total_TSLA_holding    |
# | total_XOM_holding     |
# | total_NFLX_holding    |
# | total_PG_holding      |
# | TSLA_value            |
# | XOM_value             |
# | NFLX_value            |
# | PG_value              |
#
# Strategy Columns (After Rename):
#
# | Strategy Columns   |
# |--------------------|
# | TimePre            |
# | Name               |
# | Participant_ID     |
# | PRM1_5             |
# | PRM1_6             |
# | PRM1_7             |
# | PRM1_8             |
# | PRM1_9             |
# | PRM1_10            |
# | PRM1_11            |
# | PRM1_12            |
# | PRM1_12a           |
# | PRM2a_1            |
# | PRM2a_2            |
# | PRM2a_3            |
# | PRM2a_4            |
# | PRM2b_1            |
# | PRM2b_2            |
# | PRM2b_4            |
# | PRM2b_5            |
# | PRM2b_6            |
# | PRM2b_7            |
# | PRM2b_8            |
# | PRM2b_9            |
# | PRM2b_10           |
# | PRM2b_11           |
# | PRM2b_12           |
# | PRM2b_13           |
# | PRM2b_13a          |
# | PRM2b_14           |
# | PRM2b_14a          |
# | PRM3_1             |
# | PRM3_2             |
# | PRM3_3             |
# | PRM3_4             |
# | PRM3_5             |
# | PRM3_6             |
# | PRM3_7             |
# | PRM3_8             |
# | PRM3_9             |
# | PRM3_10            |
# | PRM3_11            |
# | PRM3_12            |
# | PRM4a_1            |
# | PRM4a_1a           |
# | PRM4a_2            |
# | PRM4a_2a           |
# | PRM4a_3            |
# | PRM4a_3a           |
# | PRM4a_3b           |
# | PRM4a_4            |
# | PRM4a_4a           |
# | PRM4a_4b           |
# | PRM4a_4c           |
# | PRM4b_1            |
# | PRM4b_2            |
# | PRM4b_3            |
# | PRM4b_4            |
# | PRM4b_5            |
# | PRM4b_5a           |
# | PRM4b_6            |
# | PRM4b_7            |
# | PRM4b_7a           |
# | PRM4b_8            |
# | PRM4c_1            |
# | PRM4c_2            |
# | PRM4c_3            |
# | PRM4c_4            |
# | PRM4c_5            |
# | PRM4c_6            |
# | PRM4c_7            |
# | PRM4c_8            |
# | PRM4c_8a           |
# | PRM4c_9            |
# | PRM2b_3            |
# | PRM4b_4a           |
# | PRM4b_5b           |
# | PRM4b_5c           |
# | TimePost           |
# | POM2_1             |
# | POM2_2             |
# | POM2_2a            |
# | POM2_3             |
# | POM2_3a            |
# | POM2_4             |
# | POM2_4a            |
# | POM2_5             |
# | POM2_5a            |
# | POM2_6             |
# | POM2_7             |
# | POM2_8             |
# | POM2_9             |
# | POM2_9a            |
# | POM3_1             |
# | POM3_2             |
# | POM3_3             |
# | POM4a_1            |
# | POM4a_2            |
# | POM4a_3            |
# | POM4a_4            |
# | POM4a_5            |
# | POM4a_6            |
# | POM4a_7            |
# | POM4a_8            |
# | POM4b_1_T          |
# | POM4b_1_X          |
# | POM4b_1_N          |
# | POM4b_1_P          |
# | POM4b_2_T          |
# | POM4b_2_X          |
# | POM4b_2_N          |
# | POM4b_2_P          |
# | POM4b_3_G          |
# | POM4b_3_DT         |
# | POM4b_3_NH         |
# | POM4b_4_OC         |
# | POM4b_4_HL         |
# | POM4b_4_V          |
# | POM4b_4_BB         |
# | POM4b_4_MACD       |
# | POM5_1             |
# | POM5_2             |
# | POM5_3             |
# | POM5_4             |
# | Stock_1st          |
# | Stock_2nd          |
# | Stock_3rd          |
# | Stock_4th          |
# | Risky_1st          |
# | Risky_2nd          |
# | Risky_3rd          |
# | Risky_4th          |
# | DecisionFactor_1st |
# | DecisionFactor_2nd |
# | DecisionFactor_3rd |
# | Indicator_1st      |
# | Indicator_2nd      |
# | Indicator_3rd      |
# | Indicator_4th      |
# | Indicator_5th      |
# The renamed merged_log and strategy have been exported to: E:\FYP\FYP Symposium\Renamed_Merged_Log_and_Strategy.xlsx

# %%
strategy.head(15)
# Out:
#                 TimePre                      Name Participant_ID PRM1_5  \
# 0   23/04/2025 10:30:52          Daniyaal Bokhari          E0070   Male
# 1   26/04/2025 16:37:36         Zohaib Ali Mughal          E0169   Male
# 2    12apr2025 14:58:20              Daniyal Inam          E0426   Male
# 3    12apr2025 15:05:14      Mohammad Tayyab Alam          E0712   Male
# 4    14apr2025 13:10:50  Muhammad Hassan Ali Khan          E1130   Male
# 5    11apr2025 15:30:57       Nashit Karim Munshi          E1217   Male
# 6    11apr2025 16:05:20        Mir Mustafa Baloch          E1719   Male
# 7    08apr2025 11:50:27            Junaid Sagheer          E2010   Male
# 8    10apr2025 12:39:49              Maisam Nazim          E2514   Male
# 9    10apr2025 17:09:36             Huzaifa Rehan          E3007   Male
# 10   09apr2025 12:22:12             Karam Hussain          E3508   Male
# 11   08apr2025 16:12:39              Safwan Adnan          E3704   Male
# 12   10apr2025 12:13:32             Hamza Hussain          E4011   Male
# 13   12apr2025 15:46:35       Abdus Sattar Sohail          E4524   Male
# 14   28mar2025 15:24:44           Syed Saad Hasan          E5002   Male
#
#     PRM1_6                 PRM1_7 PRM1_8   PRM1_9  PRM1_10  \
# 0       19              Bachelors     No     Urdu        4
# 1       23              Bachelors     No     Urdu        4
# 2       24              Bachelors    Yes     Urdu        5
# 3       22              Bachelors    Yes     Urdu        5
# 4       20  Intermediate/A levels    Yes     Urdu        4
# 5       35                Masters    Yes     Urdu        5
# 6       21              Bachelors    Yes  Balochi        4
# 7       20              Bachelors    Yes     Urdu        3
# 8       22              Bachelors    Yes     Urdu        3
# 9       22              Bachelors    Yes     Urdu        4
# 10      21              Bachelors     No     Urdu        4
# 11      21              Bachelors     No     Urdu        5
# 12      20              Bachelors    Yes     Urdu        3
# 13      24              Bachelors     No     Urdu        4
# 14      22              Bachelors    Yes     Urdu        3
#
#                             PRM1_11  ... Risky_3rd Risky_4th  \
# 0                                No  ...       XOM      TSLA
# 1               Trading/Investments  ...      TSLA        PG
# 2               Trading/Investments  ...      NFLX       XOM
# 3               Trading/Investments  ...       XOM        PG
# 4               Trading/Investments  ...       XOM        PG
# 5   Multiple passive income sources  ...       XOM        PG
# 6                                No  ...      NFLX        PG
# 7           Allowance from Guardian  ...        PG       XOM
# 8                                No  ...      NFLX      TSLA
# 9           Allowance from Guardian  ...        PG       XOM
# 10              Trading/Investments  ...       XOM        PG
# 11                    Self Employed  ...       XOM        PG
# 12          Allowance from Guardian  ...      TSLA        PG
# 13              Trading/Investments  ...       XOM        PG
# 14                               No  ...       XOM        PG
#
#     DecisionFactor_1st  DecisionFactor_2nd  DecisionFactor_3rd  \
# 0                Graph          Data Table       News Headline
# 1                Graph       News Headline          Data Table
# 2        News Headline          Data Table               Graph
# 3        News Headline               Graph          Data Table
# 4                Graph       News Headline          Data Table
# 5        News Headline               Graph          Data Table
# 6        News Headline          Data Table               Graph
# 7           Data Table               Graph       News Headline
# 8           Data Table               Graph       News Headline
# 9        News Headline               Graph          Data Table
# 10               Graph       News Headline          Data Table
# 11       News Headline               Graph          Data Table
# 12       News Headline          Data Table               Graph
# 13       News Headline               Graph          Data Table
# 14          Data Table               Graph       News Headline
#
#       Indicator_1st    Indicator_2nd    Indicator_3rd    Indicator_4th  \
# 0          High/Low           Volume       Open/Close  Bollinger Bands
# 1        Open/Close  Bollinger Bands           Volume         High/Low
# 2        Open/Close         High/Low           Volume             MACD
# 3        Open/Close  Bollinger Bands             MACD           Volume
# 4   Bollinger Bands             MACD           Volume         High/Low
# 5              MACD  Bollinger Bands       Open/Close         High/Low
# 6          High/Low       Open/Close           Volume  Bollinger Bands
# 7              MACD  Bollinger Bands           Volume         High/Low
# 8        Open/Close         High/Low  Bollinger Bands             MACD
# 9              MACD           Volume         High/Low       Open/Close
# 10  Bollinger Bands         High/Low       Open/Close           Volume
# 11           Volume  Bollinger Bands         High/Low       Open/Close
# 12           Volume  Bollinger Bands             MACD         High/Low
# 13       Open/Close             MACD           Volume         High/Low
# 14       Open/Close         High/Low             MACD           Volume
#
#       Indicator_5th
# 0              MACD
# 1              MACD
# 2   Bollinger Bands
# 3          High/Low
# 4        Open/Close
# 5            Volume
# 6              MACD
# 7        Open/Close
# 8            Volume
# 9   Bollinger Bands
# 10             MACD
# 11             MACD
# 12       Open/Close
# 13  Bollinger Bands
# 14  Bollinger Bands
#
# [15 rows x 140 columns]
